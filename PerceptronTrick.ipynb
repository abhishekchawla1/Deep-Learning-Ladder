# %%
from sklearn.datasets import make_classification

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# Out:
# C:\Users\ASUS\AppData\Roaming\Python\Python310\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
X,y=make_classification(n_samples=1000,n_features=3,n_informative=1,n_redundant=0,n_clusters_per_class=1,n_classes=2,class_sep=5)

# %%
X
# Out:
# array([[ 0.24858489,  1.10826558,  5.27426564],
#        [-0.34128252,  1.04009231, -3.91469545],
#        [-1.59454325, -0.78629607, -5.68460845],
#        ...,
#        [ 1.13363315, -0.12572451,  5.25162204],
#        [ 0.87012031,  1.49808608, -5.73673184],
#        [ 1.3560029 ,  2.04223172,  4.4745848 ]])

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(X[:, 0], X[:, 1], X[:, 2], c=y)
plt.show()

# %%
def perceptron(X,y):
    
    X = np.insert(X,0,1,axis=1)
    weights = np.ones(X.shape[1])
    lr = 0.1
    
    for i in range(1000):
        j = np.random.randint(0,100)
        y_hat = step(np.dot(X[j],weights))
        weights = weights + lr*(y[j]-y_hat)*X[j]
        
    return weights[0],weights[1:]

# %%
def step(x):
    if x>0:
        return 1
    else:
        return 0

# %%
intercept,coef=perceptron(X,y)
